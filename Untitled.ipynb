# %%
# !pip install 'PyPDF2<3.0'
# !pip install PyMuPDF
# !pip install matplotlib
# !pip install pandas
# !pip install numpy
# !pip install tabula-py
# !pip install "camelot-py[base]"
# !pip install opencv-python
# Out:
# The system cannot find the file specified.
# Requirement already satisfied: PyMuPDF in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (1.24.10)
# Requirement already satisfied: PyMuPDFb==1.24.10 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from PyMuPDF) (1.24.10)
# [notice] A new release of pip available: 22.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (3.9.2)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: pillow>=8 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: cycler>=0.10 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: numpy>=1.23 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from matplotlib) (2.1.1)
# Requirement already satisfied: six>=1.5 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip available: 22.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: numpy>=1.22.4 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from pandas) (2.1.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip available: 22.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (2.1.1)
# [notice] A new release of pip available: 22.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tabula-py in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (2.9.3)
# Requirement already satisfied: pandas>=0.25.3 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from tabula-py) (2.2.2)
# Requirement already satisfied: numpy in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from tabula-py) (2.1.1)
# Requirement already satisfied: distro in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from tabula-py) (1.9.0)
# Requirement already satisfied: tzdata>=2022.7 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from pandas>=0.25.3->tabula-py) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from pandas>=0.25.3->tabula-py) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from pandas>=0.25.3->tabula-py) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.25.3->tabula-py) (1.16.0)
# [notice] A new release of pip available: 22.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: camelot-py[base] in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (0.9.0)
# Requirement already satisfied: numpy>=1.13.3 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[base]) (2.1.1)
# Requirement already satisfied: chardet>=3.0.4 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[base]) (5.2.0)
# Requirement already satisfied: pandas>=0.23.4 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[base]) (2.2.2)
# Requirement already satisfied: click>=6.7 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[base]) (8.1.7)
# Requirement already satisfied: openpyxl>=2.5.8 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[base]) (3.1.5)
# Requirement already satisfied: PyPDF2>=1.26.0 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[base]) (3.0.1)
# Requirement already satisfied: pdfminer.six>=20200726 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[base]) (20240706)
# Requirement already satisfied: colorama in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from click>=6.7->camelot-py[base]) (0.4.6)
# Requirement already satisfied: et-xmlfile in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from openpyxl>=2.5.8->camelot-py[base]) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from pandas>=0.23.4->camelot-py[base]) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from pandas>=0.23.4->camelot-py[base]) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from pandas>=0.23.4->camelot-py[base]) (2024.2)
# Requirement already satisfied: cryptography>=36.0.0 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from pdfminer.six>=20200726->camelot-py[base]) (43.0.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from pdfminer.six>=20200726->camelot-py[base]) (3.3.2)
# Requirement already satisfied: cffi>=1.12 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from cryptography>=36.0.0->pdfminer.six>=20200726->camelot-py[base]) (1.17.1)
# Requirement already satisfied: six>=1.5 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23.4->camelot-py[base]) (1.16.0)
# Requirement already satisfied: pycparser in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six>=20200726->camelot-py[base]) (2.22)
# WARNING: camelot-py 0.9.0 does not provide the extra 'base'
#
# [notice] A new release of pip available: 22.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: opencv-python in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from opencv-python) (2.1.1)
# [notice] A new release of pip available: 22.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install PyPDF2==2.12.1
# !pip install ghostscript
# !pip install camelot-py[cv]
# !pip install excalibur-py
# !apt install ghostscript python3-tk
# Out:
# Requirement already satisfied: PyPDF2==2.12.1 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (2.12.1)
# [notice] A new release of pip available: 22.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting ghostscript
#   Using cached ghostscript-0.7-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: setuptools>=38.6.0 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from ghostscript) (63.2.0)
# Installing collected packages: ghostscript
# Successfully installed ghostscript-0.7
# [notice] A new release of pip available: 22.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: camelot-py[cv] in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (0.9.0)
# Requirement already satisfied: openpyxl>=2.5.8 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[cv]) (3.1.5)
# Requirement already satisfied: numpy>=1.13.3 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[cv]) (2.1.1)
# Requirement already satisfied: pandas>=0.23.4 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[cv]) (2.2.2)
# Requirement already satisfied: pdfminer.six>=20200726 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[cv]) (20240706)
# Requirement already satisfied: PyPDF2>=1.26.0 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[cv]) (2.12.1)
# Requirement already satisfied: click>=6.7 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[cv]) (8.1.7)
# Requirement already satisfied: chardet>=3.0.4 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[cv]) (5.2.0)
# Requirement already satisfied: opencv-python>=3.4.2.17 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[cv]) (4.10.0.84)
# Requirement already satisfied: colorama in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from click>=6.7->camelot-py[cv]) (0.4.6)
# Requirement already satisfied: et-xmlfile in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from openpyxl>=2.5.8->camelot-py[cv]) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from pandas>=0.23.4->camelot-py[cv]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from pandas>=0.23.4->camelot-py[cv]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from pandas>=0.23.4->camelot-py[cv]) (2024.1)
# Requirement already satisfied: cryptography>=36.0.0 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from pdfminer.six>=20200726->camelot-py[cv]) (43.0.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from pdfminer.six>=20200726->camelot-py[cv]) (3.3.2)
# Requirement already satisfied: cffi>=1.12 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from cryptography>=36.0.0->pdfminer.six>=20200726->camelot-py[cv]) (1.17.1)
# Requirement already satisfied: six>=1.5 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23.4->camelot-py[cv]) (1.16.0)
# Requirement already satisfied: pycparser in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six>=20200726->camelot-py[cv]) (2.22)
# [notice] A new release of pip available: 22.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting excalibur-py
#   Downloading excalibur_py-0.4.3-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 9.5 MB/s eta 0:00:00
# Collecting Werkzeug<1.0.0
#   Downloading Werkzeug-0.16.1-py2.py3-none-any.whl (327 kB)
#      ------------------------------------- 327.4/327.4 kB 19.8 MB/s eta 0:00:00
# Collecting configparser<3.6.0,>=3.5.0
#   Downloading configparser-3.5.3-py3-none-any.whl (21 kB)
# Requirement already satisfied: camelot-py[cv]>=0.7.1 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from excalibur-py) (0.9.0)
# Collecting celery>=4.1.1
#   Downloading celery-5.4.0-py3-none-any.whl (425 kB)
#      ------------------------------------- 426.0/426.0 kB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: Click>=7.0 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from excalibur-py) (8.1.7)
# Collecting Flask>=1.0.2
#   Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#      ---------------------------------------- 101.7/101.7 kB ? eta 0:00:00
# Collecting SQLAlchemy>=1.2.12
#   Downloading SQLAlchemy-2.0.34-cp310-cp310-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 33.5 MB/s eta 0:00:00
# Requirement already satisfied: openpyxl>=2.5.8 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[cv]>=0.7.1->excalibur-py) (3.1.5)
# Requirement already satisfied: PyPDF2>=1.26.0 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[cv]>=0.7.1->excalibur-py) (2.12.1)
# Requirement already satisfied: pdfminer.six>=20200726 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[cv]>=0.7.1->excalibur-py) (20240706)
# Requirement already satisfied: pandas>=0.23.4 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[cv]>=0.7.1->excalibur-py) (2.2.2)
# Requirement already satisfied: chardet>=3.0.4 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[cv]>=0.7.1->excalibur-py) (5.2.0)
# Requirement already satisfied: numpy>=1.13.3 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[cv]>=0.7.1->excalibur-py) (2.1.1)
# Requirement already satisfied: opencv-python>=3.4.2.17 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from camelot-py[cv]>=0.7.1->excalibur-py) (4.10.0.84)
# Collecting vine<6.0,>=5.1.0
#   Downloading vine-5.1.0-py3-none-any.whl (9.6 kB)
# Collecting kombu<6.0,>=5.3.4
#   Downloading kombu-5.4.1-py3-none-any.whl (201 kB)
#      ------------------------------------- 201.3/201.3 kB 12.7 MB/s eta 0:00:00
# Collecting click-plugins>=1.1.1
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting click-repl>=0.2.0
#   Downloading click_repl-0.3.0-py3-none-any.whl (10 kB)
# Collecting click-didyoumean>=0.3.0
#   Downloading click_didyoumean-0.3.1-py3-none-any.whl (3.6 kB)
# Collecting billiard<5.0,>=4.2.0
#   Downloading billiard-4.2.0-py3-none-any.whl (86 kB)
#      ---------------------------------------- 86.7/86.7 kB ? eta 0:00:00
# Requirement already satisfied: tzdata>=2022.7 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from celery>=4.1.1->excalibur-py) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from celery>=4.1.1->excalibur-py) (2.9.0.post0)
# Requirement already satisfied: colorama in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from Click>=7.0->excalibur-py) (0.4.6)
# Collecting blinker>=1.6.2
#   Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: Jinja2>=3.1.2 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from Flask>=1.0.2->excalibur-py) (3.1.4)
# Collecting Flask>=1.0.2
#   Using cached flask-3.0.2-py3-none-any.whl (101 kB)
#   Downloading flask-3.0.1-py3-none-any.whl (101 kB)
#      ---------------------------------------- 101.2/101.2 kB ? eta 0:00:00
#   Downloading flask-3.0.0-py3-none-any.whl (99 kB)
#      ---------------------------------------- 99.7/99.7 kB 5.6 MB/s eta 0:00:00
#   Downloading flask-2.3.3-py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.1/96.1 kB 5.4 MB/s eta 0:00:00
#   Downloading Flask-2.3.2-py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.9/96.9 kB ? eta 0:00:00
#   Downloading Flask-2.3.1-py3-none-any.whl (96 kB)
#      ---------------------------------------- 97.0/97.0 kB ? eta 0:00:00
#   Downloading Flask-2.3.0-py3-none-any.whl (96 kB)
#      ---------------------------------------- 97.0/97.0 kB ? eta 0:00:00
#   Downloading Flask-2.2.5-py3-none-any.whl (101 kB)
#      ---------------------------------------- 101.8/101.8 kB ? eta 0:00:00
#   Downloading Flask-2.2.4-py3-none-any.whl (101 kB)
#      ---------------------------------------- 101.7/101.7 kB ? eta 0:00:00
#   Downloading Flask-2.2.3-py3-none-any.whl (101 kB)
#      -------------------------------------- 101.8/101.8 kB 5.7 MB/s eta 0:00:00
#   Downloading Flask-2.2.2-py3-none-any.whl (101 kB)
#      ---------------------------------------- 101.5/101.5 kB ? eta 0:00:00
#   Downloading Flask-2.2.1-py3-none-any.whl (101 kB)
#      ---------------------------------------- 101.5/101.5 kB ? eta 0:00:00
#   Downloading Flask-2.2.0-py3-none-any.whl (101 kB)
#      ---------------------------------------- 101.1/101.1 kB ? eta 0:00:00
#   Downloading Flask-2.1.3-py3-none-any.whl (95 kB)
#      ---------------------------------------- 95.6/95.6 kB 5.7 MB/s eta 0:00:00
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Collecting Flask>=1.0.2
#   Downloading Flask-2.1.2-py3-none-any.whl (95 kB)
#      ---------------------------------------- 95.2/95.2 kB ? eta 0:00:00
#   Downloading Flask-2.1.1-py3-none-any.whl (95 kB)
#      ---------------------------------------- 95.2/95.2 kB ? eta 0:00:00
#   Downloading Flask-2.1.0-py3-none-any.whl (95 kB)
#      ---------------------------------------- 95.2/95.2 kB 5.7 MB/s eta 0:00:00
#   Downloading Flask-2.0.3-py3-none-any.whl (95 kB)
#      ---------------------------------------- 95.6/95.6 kB 5.7 MB/s eta 0:00:00
#   Downloading Flask-2.0.2-py3-none-any.whl (95 kB)
#      ---------------------------------------- 95.2/95.2 kB ? eta 0:00:00
#   Downloading Flask-2.0.1-py3-none-any.whl (94 kB)
#      ---------------------------------------- 94.8/94.8 kB ? eta 0:00:00
#   Downloading Flask-2.0.0-py3-none-any.whl (93 kB)
#      ---------------------------------------- 93.2/93.2 kB ? eta 0:00:00
#   Downloading Flask-1.1.4-py2.py3-none-any.whl (94 kB)
#      ---------------------------------------- 94.6/94.6 kB ? eta 0:00:00
# Collecting itsdangerous<2.0,>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting Jinja2<3.0,>=2.10.1
#   Downloading Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
#      ---------------------------------------- 125.7/125.7 kB ? eta 0:00:00
# Collecting Flask>=1.0.2
#   Downloading Flask-1.1.3-py2.py3-none-any.whl (94 kB)
#      ---------------------------------------- 94.6/94.6 kB ? eta 0:00:00
#   Downloading Flask-1.1.2-py2.py3-none-any.whl (94 kB)
#      ---------------------------------------- 94.6/94.6 kB ? eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.6.0 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from SQLAlchemy>=1.2.12->excalibur-py) (4.12.2)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-3.1.0-cp310-cp310-win_amd64.whl (293 kB)
#      ------------------------------------- 293.3/293.3 kB 18.9 MB/s eta 0:00:00
# Requirement already satisfied: prompt-toolkit>=3.0.36 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from click-repl>=0.2.0->celery>=4.1.1->excalibur-py) (3.0.47)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from Jinja2>=3.1.2->Flask>=1.0.2->excalibur-py) (2.1.5)
# Collecting amqp<6.0.0,>=5.1.1
#   Downloading amqp-5.2.0-py3-none-any.whl (50 kB)
#      ---------------------------------------- 50.9/50.9 kB ? eta 0:00:00
# Requirement already satisfied: et-xmlfile in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from openpyxl>=2.5.8->camelot-py[cv]>=0.7.1->excalibur-py) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from pandas>=0.23.4->camelot-py[cv]>=0.7.1->excalibur-py) (2024.2)
# Requirement already satisfied: charset-normalizer>=2.0.0 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from pdfminer.six>=20200726->camelot-py[cv]>=0.7.1->excalibur-py) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from pdfminer.six>=20200726->camelot-py[cv]>=0.7.1->excalibur-py) (43.0.1)
# Requirement already satisfied: six>=1.5 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from python-dateutil>=2.8.2->celery>=4.1.1->excalibur-py) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from cryptography>=36.0.0->pdfminer.six>=20200726->camelot-py[cv]>=0.7.1->excalibur-py) (1.17.1)
# Requirement already satisfied: wcwidth in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery>=4.1.1->excalibur-py) (0.2.13)
# Requirement already satisfied: pycparser in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six>=20200726->camelot-py[cv]>=0.7.1->excalibur-py) (2.22)
# Installing collected packages: Werkzeug, vine, itsdangerous, greenlet, configparser, billiard, SQLAlchemy, Flask, click-repl, click-plugins, click-didyoumean, amqp, kombu, celery, excalibur-py
# Successfully installed Flask-1.1.2 SQLAlchemy-2.0.34 Werkzeug-0.16.1 amqp-5.2.0 billiard-4.2.0 celery-5.4.0 click-didyoumean-0.3.1 click-plugins-1.1.1 click-repl-0.3.0 configparser-3.5.3 excalibur-py-0.4.3 greenlet-3.1.0 itsdangerous-2.2.0 kombu-5.4.1 vine-5.1.0
# [notice] A new release of pip available: 22.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# 'apt' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# # Overview data

# %%
import pandas as pd

# %%
import pymupdf # imports the pymupdf library
import fitz  # import PyMuPDF
doc = pymupdf.open("file-sao-ke.pdf") # open a document

print("doc lens:", len(doc))
# Out:
# doc lens: 12028

# %%
"""
Utility function for showing images.

Intended to be imported in Jupyter notebooks to display pixmap images.

Invocation: "show_image(item, title)", where item is a PyMuPDF object
which has a "get_pixmap" method, and title is an optional string.

The function executes "item.get_pixmap(dpi=150)" and show the resulting
image.


Dependencies
------------
numpy, matplotlib, pymupdf
"""


def show_image(item, title=""):
    """Display a pixmap.

    Just to display Pixmap image of "item" - ignore the man behind the curtain.

    Args:
        item: any PyMuPDF object having a "get_pixmap" method.
        title: a string to be used as image title

    Generates an RGB Pixmap from item using a constant DPI and using matplotlib
    to show it inline of the notebook.
    """
    DPI = 150  # use this resolution
    import numpy as np
    import matplotlib.pyplot as plt

    # %matplotlib inline
    pix = item.get_pixmap(dpi=DPI)
    img = np.ndarray([pix.h, pix.w, 3], dtype=np.uint8, buffer=pix.samples_mv)
    plt.figure(dpi=DPI)  # set the figure's DPI
    plt.title(title)  # set title of image
    _ = plt.imshow(img, extent=(0, pix.w * 72 / DPI, pix.h * 72 / DPI, 0))

# %%
clip_rect = [10, 240, 700, 750]

for page in doc[1:2]: # iterate the document pages
    text = page.find_tables()  # get plain text encoded as UTF-8
    print(text)

tabs = doc[0].find_tables(clip=clip_rect, strategy='text', min_words_vertical=8, min_words_horizontal=1)

old_column_names
for i,tab in enumerate(tabs):  # iterate over all tables
    for cell in tab.header.cells:
        page.draw_rect(cell,color=fitz.pdfcolor["red"],width=0.3)
    page.draw_rect(tab.bbox,color=fitz.pdfcolor["green"])
    print(f"Table {i} column names: {tab.header.names}, external: {tab.header.external}")
    old_column_names = tab.header.names
    print(old_column_names)

tab = tabs[0]
df = tab.to_pandas()
show_image(page, f"Table & Header BBoxes")

df.columns = ['Col1', 'Col2', 'Col3']
df.loc[-1] = old_column_names  # Add new row at index -1
df.index = df.index + 1        # Shift index
df = df.sort_index()           # Sort index to make the new row the first one
df
# Out:
# <pymupdf.table.TableFinder object at 0x0000020BB3205B40>
# Table 0 column names: ['01/09/2024', '', ''], external: False
# ['01/09/2024', '', '']
#           Col1    Col2                                 Col3
# 0   01/09/2024    Col1                                 Col2
# 1               50.000      292976.010924.013647.xin cam on
# 2   5213.45946
# 3
# 4   01/09/2024
# ..         ...     ...                                  ...
# 67
# 68  01/09/2024
# 69               6.000  266303.010924.122804.NGUYEN THI MAO
# 70  5219.94264
# 71                                              Chuyen tien
#
# [72 rows x 3 columns]

# %%
df.columns.tolist()
# Out:
# ['Col1', 'Col2', 'Col3']

# %%
tab = tabs[0]
df = tab.to_pandas()
data = df.values

# %%
def process_data(data):
    # Regex pattern to identify valid date (dd/mm/yyyy)
    date_pattern = re.compile(r'\d{2}/\d{2}/\d{4}')
    
    # Initialize empty list for cleaned rows
    cleaned_data = []
    current_row = {"Date": None, "ID": None, "Amount": None, "Content": ""}
    
    # Iterate through the data
    for row in data:
        if row[0] and date_pattern.match(row[0]):  # New date found
            if current_row["Date"]:  # Add current row before starting a new one
                cleaned_data.append(current_row.copy())
            current_row["Date"] = row[0]
            current_row["ID"] = None
            current_row["Amount"] = None
            current_row["Content"] = ""
        elif row[0] and not row[1]:  # ID found
            current_row["ID"] = row[0]
        if row[1]:  # Amount found
            current_row["Amount"] = row[1]
        if row[2]:  # Content found
            current_row["Content"] += row[2] + " "
    
    # Add the last row
    if current_row["Date"]:
        cleaned_data.append(current_row.copy())
    
    # Create DataFrame
    new_df = pd.DataFrame(cleaned_data)
    
    # Display the reformatted DataFrame
    return new_df
process_data(data)
# Out:
#           Date          ID  Amount  \
# 0   01/09/2024  5090.85797  20.000
# 1   01/09/2024  5241.83107  29.000
# 2   01/09/2024  5218.87149   3.000
# 3   01/09/2024  5388.96713   3.000
# 4   01/09/2024  5212.91607   3.000
# 5   01/09/2024  5220.28596   3.000
# 6   01/09/2024  5388.33462   3.000
# 7   01/09/2024  5216.68569   3.000
# 8   01/09/2024  5387.37142   3.000
# 9   01/09/2024  5161.94345  10.000
# 10  01/09/2024  5219.94264   6.000
#
#                                               Content
# 0   VCB.CTDK.31/03/2024.ADIDA PHAT. CT tu 04810007...
# 1   MBVCB.6916176124.CAO VIET TUAN chuyen tien.CT ...
# 2        272986.010924.101858.DO DUC LOI chuyen tien
# 3   020097040509011046122024JDC5013867.96713 .1046...
# 4       529474.010924.112032.BUI VAN DAI chuyen tien
# 5           577301.010924.113215.DO DUC LOI MHS 4242
# 6   020097040509011137472024Y7ZE058213.33462 .1137...
# 7   761664.010924.121847.NGUYEN VAN TUAN chuyen tien
# 8   0200970405090112202020246WVI059470.3714 2.1220...
# 9   PARTNER.DIRECT_DEBITS_VCB.ZLP.ZP6R 34H953F5.20...
# 10   266303.010924.122804.NGUYEN THI MAO Chuyen tien

# %%
import re
date_time_regex = r"^\b(0[1-9]|[12][0-9]|3[01])\/(0[1-9]|1[0-2])\/\d{4}\b$"
transaction_id_regex = r"^\b\d+\.\d+$"

col_id_name = "Ngày GD/\nTNX Date\nSố CT/ Doc No"
col_debit_name = "Số tiền ghi nợ/\nDebit"
col_credit_name = "Số tiền ghi có/\nCredit"
col_txdetail_name = "Nội dung chi tiết/\nTransactions in detail"

# %%
df
# Out:
#     01/09/2024    Col1                                   Col2
# 0               50.000        292976.010924.013647.xin cam on
# 1   5213.45946
# 2
# 3   01/09/2024
# 4               20.000  VCB.CTDK.31/03/2024.ADIDA PHAT. CT tu
# ..         ...     ...                                    ...
# 66
# 67  01/09/2024
# 68               6.000    266303.010924.122804.NGUYEN THI MAO
# 69  5219.94264
# 70                                                Chuyen tien
#
# [71 rows x 3 columns]

# %%
# !pip install tqdm
# Out:
# Collecting tqdm
#   Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.4/78.4 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: colorama in d:\letmeyclear\tuthienalyze\venv\lib\site-packages (from tqdm) (0.4.6)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.66.5
# [notice] A new release of pip available: 22.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tqdm import tqdm

clip_rect = [0, 0, 800, 750]

df_raw = pd.DataFrame(columns=['Date', 'ID', 'Amount', 'Content'])

for page in tqdm(doc[1:50]): # iterate the document pages
    # text = page.find_tables()  # get plain text encoded as UTF-8
    tabs = page.find_tables(clip=clip_rect, strategy='text', min_words_vertical=4, min_words_horizontal=1)
    
    old_column_names = tabs[0].header.names
    
    tab = tabs[0]
    df = tab.to_pandas()
    try:
        df.columns = ['Col1', 'Col2', 'Col3']
        df.loc[-1] = old_column_names  # Add new row at index -1
        df.index = df.index + 1        # Shift index
        df = df.sort_index()           # Sort index to make the new row the first one
        new_df = process_data(df.values)
        df_raw = pd.concat([df_raw, new_df], ignore_index=True)
    except Exception as e:
        print(df)
        for i,tab in enumerate(tabs):  # iterate over all tables
            for cell in tab.header.cells:
                page.draw_rect(cell,color=fitz.pdfcolor["red"],width=0.3)
            page.draw_rect(tab.bbox,color=fitz.pdfcolor["green"])
            print(f"Table {i} column names: {tab.header.names}, external: {tab.header.external}")
            old_column_names = tab.header.names
            print(old_column_names)
        show_image(page, f"Table & Header BBoxes")
# Out:
#  59%|████████████████████████████████████████████████▌                                 | 29/49 [00:06<00:04,  4.37it/s]
#      08/09/2024     Col1                               Col2   Col3
# 0                500.000      MBVCB.6978231666.NGUYEN THI T     HU
# 1    5243.58277
# 2                              HIEN UNG HO KHAC PHUC HAU QU      A
# 3
# 4                         BAO SO 3 YAGI.CT tu 0121000620562
# ..          ...      ...                                ...    ...
# 103              200.000    114175.080924.195234.NGUYEN DOA      N
# 104  5217.73512
# 105                              XUAN TRANG UNG HO KHAC PHU  C HAU
# 106
# 107                         QUA BAO SO 3 YAGI FT24253179200    515
#
# [108 rows x 4 columns]
# Table 0 column names: ['08/09/2024', 'Col1', 'Col2', 'Col3'], external: False
# ['08/09/2024', 'Col1', 'Col2', 'Col3']
# 100%|██████████████████████████████████████████████████████████████████████████████████| 49/49 [00:11<00:00,  4.34it/s]

# %%
def process_balance(input_text):
    input_text = input_text.strip()
    input_text = input_text.split(' ')[0]
    input_text = input_text.replace('.', '')
    input_text = input_text.strip()
    return int(input_text)

# %%
df_temp = df_raw.dropna(subset='Amount')

# %%
nan_rows = df_temp[df_temp['Amount'].isna()]
nan_rows
# Out:
# Empty DataFrame
# Columns: [Date, ID, Amount, Content]
# Index: []

# %%
df_temp['Amount'] = df_temp['Amount'].apply(process_balance)
df_temp
# Out:
# C:\Users\thanh\AppData\Local\Temp\ipykernel_4388\1110328025.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp['Amount'] = df_temp['Amount'].apply(process_balance)
#            Date          ID  Amount  \
# 0    01/09/2024  5215.97152    3000
# 1    01/09/2024  5219.24714   10000
# 2    02/09/2024  5212.22965   10000
# 3    02/09/2024  5245.21394   10000
# 4    02/09/2024  5078.73943   50000
# ..          ...         ...     ...
# 774  09/09/2024  5215.31355  200000
# 775  09/09/2024  5389.25422   50000
# 776  09/09/2024  5239.96871   50000
# 777  09/09/2024  5216.31716   50000
# 778  09/09/2024  5239.96891  200000
#
#                                                Content
# 0    Col2 267515.010924.122904.NGUYEN THI MAO Chuye...
# 1    018806.010924.213139.chuc mung ngay 29 nuoc co...
# 2    055464.020924.064157.Ung Ho Nha Nuoc Viet Nam ...
# 3    MBVCB.6924605040.gia dinh Dung Thuy Giang chuc...
# 4    MBVCB.6925071164.mung ngay quoc khanh.CT tu 10...
# ..                                                 ...
# 774  183251.080924.234437.Nguyen Ngoc Linh ck ung h...
# 775  020097040509082345002024ZDFL053372.2542 2.2345...
# 776  MBVCB.6979627562.Lee Gumayusi Minhyung ung ho ...
# 777  713116.080924.234528.Ho tro dong bao khac phuc...
# 778  MBVCB.6979627902.DUONG THI THAO khacphuchauqua...
#
# [778 rows x 4 columns]

# %%
df_temp.plot.hist(column=["Amount"])
# Out:
# <Axes: ylabel='Frequency'>
